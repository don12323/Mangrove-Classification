# %%
import os
#from patchify import patchify
import rasterio as rio
from rasterio.windows import Window
import numpy as np

# %%
NEO_path = "/mnt/c/Users/Imesh/Desktop/summer_proj/MAPQ3389-EnSTAR"


patch_dir = os.path.join(NEO_path, 'patches')
image_dir = os.path.join(patch_dir, "images")
mask_dir = os.path.join(patch_dir, "labels")

# %%
[f for f in os.listdir(image_dir) if f.endswith(".tif")]
# Out:
# ['patch_000000_016769.tif',
#  'patch_000000_017178.tif',
#  'patch_000000_017587.tif',
#  'patch_000000_017996.tif',
#  'patch_000000_018405.tif',
#  'patch_000000_018814.tif',
#  'patch_000409_015542.tif',
#  'patch_000409_015951.tif',
#  'patch_000409_016360.tif',
#  'patch_000409_016769.tif',
#  'patch_000409_017178.tif',
#  'patch_000409_017587.tif',
#  'patch_000409_017996.tif',
#  'patch_000409_018405.tif',
#  'patch_000409_018814.tif',
#  'patch_000409_019223.tif',
#  'patch_000409_019632.tif',
#  'patch_000409_020041.tif',
#  'patch_000818_014724.tif',
#  'patch_000818_015133.tif',
#  'patch_000818_015542.tif',
#  'patch_000818_015951.tif',
#  'patch_000818_016360.tif',
#  'patch_000818_016769.tif',
#  'patch_000818_017178.tif',
#  'patch_000818_017587.tif',
#  'patch_000818_017996.tif',
#  'patch_000818_018405.tif',
#  'patch_000818_018814.tif',
#  'patch_000818_019223.tif',
#  'patch_000818_019632.tif',
#  'patch_000818_020041.tif',
#  'patch_000818_020450.tif',
# ...

# %%
os.listdir(mask_dir)
# Out:
# ['mask_000000_016769.tif',
#  'mask_000000_017178.tif',
#  'mask_000000_017587.tif',
#  'mask_000000_017996.tif',
#  'mask_000000_018405.tif',
#  'mask_000000_018814.tif',
#  'mask_000409_015542.tif',
#  'mask_000409_015951.tif',
#  'mask_000409_016360.tif',
#  'mask_000409_016769.tif',
#  'mask_000409_017178.tif',
#  'mask_000409_017587.tif',
#  'mask_000409_017996.tif',
#  'mask_000409_018405.tif',
#  'mask_000409_018814.tif',
#  'mask_000409_019223.tif',
#  'mask_000409_019632.tif',
#  'mask_000409_020041.tif',
#  'mask_000818_014724.tif',
#  'mask_000818_015133.tif',
#  'mask_000818_015542.tif',
#  'mask_000818_015951.tif',
#  'mask_000818_016360.tif',
#  'mask_000818_016769.tif',
#  'mask_000818_017178.tif',
#  'mask_000818_017587.tif',
#  'mask_000818_017996.tif',
#  'mask_000818_018405.tif',
#  'mask_000818_018814.tif',
#  'mask_000818_019223.tif',
#  'mask_000818_019632.tif',
#  'mask_000818_020041.tif',
#  'mask_000818_020450.tif',
#  'mask_000818_020859.tif',
# ...

# %%
len(os.listdir(mask_dir)), len(os.listdir(image_dir))
# Out:
# (1931, 1931)

# %% [markdown]
# Use save_mask func from getlabels.py
